# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
# ...

# %%
import pandas as pd

# %%
data = pd.read_csv(r"F:\VIIT\advertising - advertising.csv")

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# data = pd.read_csv(r'Project ml/advertising - advertising.csv')

# %%
# data = pd.read_csv('advertising.csv')

# %%
# b) Find Shape of Data
print("Shape of Data:", data.shape)
# Out:
# Shape of Data: (200, 4)

# %%
# c) Find Missing Values
print("Missing Values:\n", data.isnull().sum())
# Out:
# Missing Values:
#  TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# d) Find Data Type of Each Column
print("Data Types:\n", data.dtypes)
# Out:
# Data Types:
#  TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
# e) Finding out Zeros
print("Count of Zeros in Each Column:\n", (data == 0).sum())
# Out:
# Count of Zeros in Each Column:
#  TV           0
# Radio        1
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# f) Indexing and Selecting Data, Sorting Data
# Selecting specific columns (e.g., Column1 and Column2)
selected_columns = data[['TV', 'Radio']]  # Replace with actual column names
print("Selected Columns:\n", selected_columns)
# Out:
# Selected Columns:
#          TV  Radio
# 0    230.1   37.8
# 1     44.5   39.3
# 2     17.2   45.9
# 3    151.5   41.3
# 4    180.8   10.8
# ..     ...    ...
# 195   38.2    3.7
# 196   94.2    4.9
# 197  177.0    9.3
# 198  283.6   42.0
# 199  232.1    8.6
#
# [200 rows x 2 columns]

# %%
data = pd.read_csv(r"F:\VIIT\GroceryStoreDataSet - GroceryStoreDataSet.csv")

# %%
print("Data Description:\n", data.describe())
print("Data Types:\n", data.dtypes)
# Out:
# Data Description:
#           MILK,BREAD,BISCUIT
# count                    19
# unique                   16
# top     BREAD,TEA,BOURNVITA
# freq                      2
# Data Types:
#  MILK,BREAD,BISCUIT    object
# dtype: object

# %%
print("Unique Values in Each Column:\n", data.nunique())
# Out:
# Unique Values in Each Column:
#  MILK,BREAD,BISCUIT    16
# dtype: int64

# %%
if 'MILK' in data.columns:  # Replace with actual string column name
    data['MILK'] = data['MILK'].str.upper()

# %%
import pandas as pd
data = pd.read_csv(r"F:\VIIT\advertising - advertising.csv")

# %%
data['TV'] = data['TV'].astype(str)  
data['Radio'] = pd.to_numeric(data['Radio'], errors='coerce') 
print("Formatted Data Types:\n", data.dtypes)
# Out:
# Formatted Data Types:
#  TV            object
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object
